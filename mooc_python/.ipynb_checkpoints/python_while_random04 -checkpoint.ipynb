# %% [markdown]
# # CalpaiV1

# %%
pi = 0

N = 100

for k in range (N):
    pi += 1/pow(16,k)*(\
        4/(8*k+1)-2/(8*k+4)-\
        1/(8*k+5)-1/(8*k+6))
print('圆周率值是:{}'.format(pi))
# Out:
# 圆周率值是:3.141592653589793

# %%
from random import random
from math import sqrt
from time import clock
Darts = 120000
hits = 0
clock()
for i in range(1, Darts):
    x, y = random(),random();
    dist = sqrt(x**2 + y**2)
    if dist <= 1.0:
        hits = hits + 1
pi  = 4 *(hits/Darts)
print('圆周率值是:{}'.format(pi))
print('程序运行的时间是:{}'.format(clock()))
# Out:
# 圆周率值是:3.1374
# 程序运行的时间是:99.613065

# %% [markdown]
# # 实例6：圆周率的计算
#  ‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# 描述
# 这是"实例"题，与课上讲解实例相同，请作答检验学习效果。‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# 求解圆周率可以采用蒙特卡罗方法，在一个正方形中撒点，根据在1/4圆内点的数量占总撒点数的比例计算圆周率值。‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# ‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫
#
# 请以123作为随机数种子，获得用户输入的撒点数量，编写程序输出圆周率的值，保留小数点后6位。
# 随机种子数 random.seed(123)

# %%
import random 
import math
import time

darts = 102400
hits = 0
clock()

random.seed(123);

for i in range(1,darts+1):
    x, y = random.random(),random.random();
    dist = sqrt(x**2+y**2) 
    if dist <=1:
        hits = hits + 1
pi = 4*(hits/darts)

# print("{:.6f}".format(pi))
print(f"我计算的pi指是 {pi:.6f}")
# Out:
# 我计算的pi指是 3.137969

# %%
random.seed(9)
x = random.random()
x
# Out:
# 0.46300735781502145

# %%
random.seed(9)
y = random.random()
y
# Out:
# 0.46300735781502145

# %%
random.random()
# Out:
# 0.37331193139504204

# %% [markdown]
# # 整数的加减和
# 描述
# 编写程序计算如下数列的值：‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# 1-2+3-4...966‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# 其中，所有数字为整数，从1开始递增，奇数为正，偶数为负‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# 输入格式
# 该题目没有输入。

# %%
import random
import math

a = 0
for i in range(4):
    if i%2 == 0:
        a -= i  # a= a - i
    else:
        a += i  # a= a + i
print("{}".format(a))
# Out:
# 2

# %% [markdown]
# # 三位水仙花数
# 描述
# "水仙花数"是指一个三位整数，其各位数字的3次方和等于该数本身。‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# 例如：ABC是一个"3位水仙花数"，则：A的3次方＋B的3次方＋C的3次方 = ABC。‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# 请按照从小到大的顺序输出所有的3位水仙花数，请用"逗号"分隔输出结果。‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‪‬ ‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# 输入输出示例
# 输出仅表示格式，不表示对错。

# %%
for i in range(1, 10):
    for j in range(10):
        for k in range(10):
            left = i * 100 + j * 10 + k
            right = i ** 3 + j ** 3 + k ** 3
            print(f'i is {i}, j is {j}, k is {k}')
            print(f'left is {left}, right is {right}')
            print(f'='*30)
            if left == right:
                print(f'result is {left}')
# Out:
# i is 1, j is 0, k is 0
# left is 100, right is 1
# ...
# i is 1, j is 0, k is 1
# left is 101, right is 2
# ...
# i is 1, j is 0, k is 2
# left is 102, right is 9
# ...
# i is 1, j is 0, k is 3
# left is 103, right is 28
# ...
# i is 1, j is 0, k is 4
# left is 104, right is 65
# ...
# i is 1, j is 0, k is 5
# left is 105, right is 126
# ...
# i is 1, j is 0, k is 6
# left is 106, right is 217
# ...
# i is 1, j is 0, k is 7
# left is 107, right is 344
# ...
# i is 1, j is 0, k is 8
# left is 108, right is 513
# ...
# i is 1, j is 0, k is 9
# left is 109, right is 730
# ...
# i is 1, j is 1, k is 0
# left is 110, right is 2
# ...
# i is 1, j is 1, k is 1
# left is 111, right is 3
# ...
# i is 1, j is 1, k is 2
# left is 112, right is 10
# ...
# i is 1, j is 1, k is 3
# left is 113, right is 29
# ...
# i is 1, j is 1, k is 4
# left is 114, right is 66
# ...
# i is 1, j is 1, k is 5
# left is 115, right is 127
# ...
# i is 1, j is 1, k is 6
# left is 116, right is 218
# ...
# i is 1, j is 1, k is 7
# left is 117, right is 345
# ...
# i is 1, j is 1, k is 8
# left is 118, right is 514
# ...

# %%
for a in range(100,1000):
    x = int(str(a)[0])
    y = int(str(a)[1])
    z = int(str(a)[2])
    if a == (x**3 +y **3 +z **3):
        print(a)
# Out:
# 153
# 370
# 371
# 407

# %% [markdown]
# # 用户登录的三次机会
#  ‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# 描述
# 给用户三次输入用户名和密码的机会，要求如下：‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# 1）如输入第一行输入用户名为‘Kate’,第二行输入密码为‘666666’，输出‘登录成功！’，退出程序；‪‬‪‬‪‬‪‬‪‬‮‬‪‬‭‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‭‬
#
# 2）当一共有3次输入用户名或密码不正确输出“3次用户名或者密码均有误！退出程序。”。

# %%
user_name = input("用户名")
pwd = input('请输入密码')
if user_name == "Kate" and pwd == "666666":
    print(f"登陆成功")
else:
    print("用户名或密码不正确")
# Out:
# 用户名Jessie
# 请输入密码123456
# 用户名或密码不正确

# %%
error_count = 0
for i in range(3):
    user_name = input("用户名")
    pwd = input('请输入密码')

    if user_name == "Kate" and pwd == "666666":
        print(f"登陆成功")
        break
    error_count += 1
    if error_count < 3:
        print("用户名或密码不正确")

if error_count == 3:
    print(f'{count}次用户名或者密码均有误！退出程序。')
# Out:
# 用户名1
# 请输入密码1
# 用户名或密码不正确
# 用户名1
# 请输入密码1
# 用户名或密码不正确
# 用户名1
# 请输入密码1
# 3次用户名或者密码均有误！退出程序。

# %%
#用户登录(三次机会)
i=0
for  i in  range(3):
    name=input()
    key=input()
    if name=='Kate' and key=='666666':
        print('登录成功!')
        break;
    i+=1
if i==3:
    print("3次用户名或者密码均有误！退出程序。")
